# %%
import numpy as np
import pandas as pd
import xarray as xr
import seaborn as sns
import cartopy.crs as crs
import cartopy.feature as cfeature
import matplotlib
import matplotlib.pyplot as plt

# %%
bathymetry = xr.open_dataset(r'D:\CRI_Modelling_PC\Bathymetry\crm.nc')

# %%
finalBath = bathymetry.Band1

# %%
lat = finalBath.lat.data
lon = finalBath.lon.data

# %%
fig = plt.figure(figsize=[40,20])

plotBath = fig.add_subplot(1,1,1,projection=crs.PlateCarree())
plotBath.set_title('Bathymetry: 2 - 24 meters',fontsize=50)

levels = [-1000,-24,-2,0,1000]

c = ('powderblue', 'limegreen', 'powderblue','beige')

plot = plotBath.contourf(lon, lat, finalBath,levels,
             transform=crs.PlateCarree(),colors=c)

plotBath.gridlines()

colorbar = fig.colorbar(plot, shrink=0.7, anchor=('SW'))
colorbar.set_label('Depth (m)',fontsize=40)
colorbar.ax.tick_params(labelsize=30)

fig.savefig(r"D:\CRI_Modelling_PC\CRI Maps\redAbaloneBath.jpeg", bbox_inches='tight')

# %%
# For later, this mask returns only the data points within the green range
# Data points outside of that range return nan
bathMask = finalBath.where((finalBath < -6) & (finalBath > -20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5e742db58027> in <module>
#       1 # For later, this mask returns only the data points within the green range
#       2 # Data points outside of that range return nan
# ----> 3 bathMask = finalBath.where((finalBath < -6) & (finalBath > -20))
#
# NameError: name 'finalBath' is not defined
